# %%
import sys
import os
sys.path.append(os.path.abspath("../.."))  # Go up two levels from notebooks to reach the root

# Now you can import using the src namespace
from src.agents.agent_workflow import MultiAssistantWithLeader
# Out:
# 2025-04-05 23:41:57,161 - src.functional.coding - INFO - Created base directory: coding
# d:\ML_DL Projects\FinBuddy\venv\lib\site-packages\pydantic\_internal\_fields.py:132: UserWarning: Field "model_client_cls" in LLMConfigEntry has conflict with protected namespace "model_".
#
# You may be able to resolve this warning by setting `model_config['protected_namespaces'] = ()`.
#   warnings.warn(
# d:\ML_DL Projects\FinBuddy\venv\lib\site-packages\pydantic\_internal\_fields.py:132: UserWarning: Field "model_client_cls" in AnthropicLLMConfigEntry has conflict with protected namespace "model_".
#
# You may be able to resolve this warning by setting `model_config['protected_namespaces'] = ()`.
#   warnings.warn(
# d:\ML_DL Projects\FinBuddy\venv\lib\site-packages\pydantic\_internal\_fields.py:132: UserWarning: Field "model_client_cls" in BedrockLLMConfigEntry has conflict with protected namespace "model_".
#
# ...
